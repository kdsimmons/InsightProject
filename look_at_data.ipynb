# %%
from sklearn.cluster import KMeans
from sklearn import preprocessing as pp
from sklearn.decomposition import PCA
import pymysql as mdb
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re 
import master_disease_list
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-62a5a52d5346> in <module>()
#       7 import numpy as np
#       8 import re
# ----> 9 import master_disease_list
#      10 get_ipython().magic(u'matplotlib inline')
#
# ImportError: No module named master_disease_list

# %%
# Get list of diseases
disease_list = master_disease_list.return_diseases()

# Set up connection to SQL
mysqlauth = pd.DataFrame.from_csv('/home/kristy/Documents/auth_codes/mysql_user.csv')
sqluser = mysqlauth.username[0]
sqlpass = mysqlauth.password[0]

con = mdb.connect(user=sqluser, host="localhost", db="charity_data", password=sqlpass, charset='utf8')

# %%
# Import data from SQL
combined_panda = pd.DataFrame()

with con:
    for disease in disease_list:
        pandadf = pd.read_sql("SELECT * FROM " + str(disease), con)
        if len(pandadf) > 0:
            combined_panda = pd.concat([combined_panda, pandadf], 0, ignore_index=True)

# %%
combined_panda.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 772 entries, 0 to 771
# Data columns (total 32 columns):
# address                772 non-null object
# age                    772 non-null float64
# bbb_accred             772 non-null float64
# bbb_link               772 non-null object
# board_size             772 non-null float64
# city                   772 non-null object
# cn_acct_transp         772 non-null float64
# cn_financial           772 non-null float64
# cn_link                772 non-null object
# cn_overall             772 non-null float64
# cn_rated               772 non-null float64
# disease                772 non-null object
# facebook_likes         772 non-null float64
# facebook_link          772 non-null object
# id                     772 non-null float64
# leader_compensation    772 non-null object
# link                   772 non-null object
# name                   772 non-null object
# percent_admin          772 non-null float64
# percent_fund           772 non-null float64
# percent_program        772 non-null float64
# purpose                772 non-null object
# staff_size             772 non-null float64
# state                  772 non-null object
# tax_exempt             772 non-null float64
# tax_status             772 non-null object
# total_contributions    772 non-null float64
# total_expenses         772 non-null float64
# total_revenue          772 non-null float64
# twitter_followers      772 non-null float64
# twitter_link           772 non-null object
# year_incorporated      772 non-null float64
# dtypes: float64(19), object(13)

# %%
# Choose features
feature_names = ['bbb_accred', 'cn_rated', 'cn_overall', 'cn_acct_transp', 'cn_financial', 'percent_admin', 'percent_fund', 'percent_program', 'staff_size', 'board_size',
                 'age', 'total_contributions', 'total_expenses', 'total_revenue', 'twitter_followers']

# %%
# Fix NaNs that were originally encoded as -1.
for idx in range(len(combined_panda)):
    if combined_panda['cn_rated'][idx] <= 0:
        for col in ['cn_overall', 'cn_acct_transp', 'cn_financial', 'percent_admin', 'percent_fund', 'percent_program', 
                    'total_contributions', 'total_expenses', 'total_revenue']:
            combined_panda[idx:(idx+1)][col] = np.nan
    if combined_panda['year_incorporated'][idx] == -1:
        combined_panda[idx:(idx+1)]['age'] = np.nan
        combined_panda[idx:(idx+1)]['year_incorporated'] = np.nan
    if combined_panda['board_size'][idx] == -1:
        combined_panda[idx:(idx+1)]['board_size'] = np.nan
    if combined_panda['staff_size'][idx] == -1:
        combined_panda[idx:(idx+1)]['staff_size'] = np.nan

# %%
combined_panda.age.describe(percentile_width=33.3)
# Out:
# count     82.000000
# mean      32.756098
# std       26.331487
# min        6.000000
# 33.4%     19.013500
# 50%       24.500000
# 66.6%     34.932500
# max      186.000000
# Name: age, dtype: float64

# %%
for col in feature_names:
    # Make histograms of each feature
    mask = combined_panda[col].apply(lambda x: int(np.isfinite(x)))
    series = combined_panda[mask==1][col]
    series = series[:,np.newaxis]
    plt.figure(figsize=[6,6]);
    plt.hist(series, bins=15)
    plt.title(col)

# %%
combined_panda[combined_panda.age > 100][['name','year_incorporated']]
# Out:
#                              name  year_incorporated
# 261     Prevent Blindness America               1908
# 265  Perkins School for the Blind               1829
#
# [2 rows x 2 columns]

# %%
features_curr = list(feature_names)
print features_curr
# Out:
# ['bbb_accred', 'cn_rated', 'cn_overall', 'cn_acct_transp', 'cn_financial', 'percent_admin', 'percent_fund', 'percent_program', 'staff_size', 'board_size', 'age', 'total_contributions', 'total_expenses', 'total_revenue', 'twitter_followers']

# %%
reduceddf = combined_panda[:][features_curr]
covdf = reduceddf.corr()
covdf[np.isnan(covdf)] = 0 # only cn_rated has NaN's, so just ignore these values
plt.figure(figsize=[8,6])
plt.pcolor(covdf);
plt.colorbar();
plt.xticks(range(len(features_curr)),features_curr, rotation=45);
plt.yticks(range(len(features_curr)),features_curr);
features_curr
# Out:
# ['bbb_accred',
#  'cn_rated',
#  'cn_overall',
#  'cn_acct_transp',
#  'cn_financial',
#  'percent_admin',
#  'percent_fund',
#  'percent_program',
#  'staff_size',
#  'board_size',
#  'age',
#  'total_contributions',
#  'total_expenses',
#  'total_revenue',
#  'twitter_followers']

# %% [markdown]
# *Ranges on correlation coefficients are visual estimates.*
#
# For aggregated diseases:
#
# High positive correlation (>.7): cn_overall#cn_acct_transp, cn_overall#cn_financial, cn_overall#percent_program, cn_financial#percent_program board_size#total_contributions#total_expense#total_revenue
#
# Medium positive correlation (.5-.7): bbb_accred#board_size, cn_acct_transp#cn_financial, cn_acct_transp#percent_program, percent_fund#staff_size, percent_admin#age, percent_fund#age, staff_size#board_size, board_size#twitter_followers
#
# Medium negative correlation (-.7--.4): cn_overall#staff_size, cn_overall#age, cn_acct_transp#percent_fund, cn_acct_transp#staff_size, cn_financial#staff_size, cn_financial#age, percent_program#staff_size, percent_program#age
#
# High negative correlation (<-.7): cn_overall#percent_fund, cn_financial#percent_fund, percent_fund#percent_program
#
# For cancer:
#
# High positive correlation (>.7): cn_overall#cn_financial, cn_overall#percent_program, staff_size#total_contributions#total_expense#total_revenue
#
# Medium positive correlation (.5-.7): cn_overall#cn_acct_transp, cn_acct_transp_cn_financial, cn_acct_transp#percent_program
#
# Medium negative correlation (-.7--.4): cn_acct_transp#percent_admin, cn_acct_transp#percent_fund, percent_admin#percent_program
#
# High negative correlation (<-.7): cn_overall#percent_fund, cn_financial#percent_fund, percent_fund#percent_program

# %%
plt.scatter(combined_panda.percent_admin, combined_panda.age);

# %%
covdf
# Out:
#                      bbb_accred  cn_rated  cn_overall  cn_acct_transp  \
# bbb_accred             1.000000  0.251265    0.332990        0.404670
# cn_rated               0.251265  1.000000    0.000000        0.000000
# cn_overall             0.332990  0.000000    1.000000        0.755345
# cn_acct_transp         0.404670  0.000000    0.755345        1.000000
# cn_financial           0.307528  0.000000    0.993234        0.678605
# percent_admin         -0.103468  0.000000   -0.272733       -0.380977
# percent_fund          -0.194459  0.000000   -0.864624       -0.533610
# percent_program        0.214923  0.000000    0.893457        0.621742
# staff_size             0.156313  0.126813   -0.266499       -0.174276
# board_size             0.096591  0.269074    0.276612       -0.028676
# age                    0.196180 -0.071478    0.026314        0.102151
# total_contributions   -0.252711  0.000000   -0.093878        0.063556
# total_expenses        -0.266936  0.000000   -0.068735        0.064774
# total_revenue         -0.266799  0.000000   -0.066852        0.064702
# twitter_followers      0.132839  0.194382    0.142002        0.223734
#
#                      cn_financial  percent_admin  percent_fund  \
# bbb_accred               0.307528      -0.103468     -0.194459
# cn_rated                 0.000000       0.000000      0.000000
# cn_overall               0.993234      -0.272733     -0.864624
# cn_acct_transp           0.678605      -0.380977     -0.533610
# cn_financial             1.000000      -0.245461     -0.878839
# percent_admin           -0.245461       1.000000      0.045487
# percent_fund            -0.878839       0.045487      1.000000
# percent_program          0.897633      -0.373093     -0.943801
# staff_size              -0.271244      -0.169904      0.287388
# board_size               0.281491      -0.068708     -0.138191
# age                      0.003011      -0.056185      0.167908
# total_contributions     -0.124588      -0.199115      0.310256
# total_expenses          -0.097166      -0.146261      0.257404
# total_revenue           -0.095069      -0.143338      0.253915
# twitter_followers        0.123382      -0.107855     -0.150382
#
#                      percent_program  staff_size  board_size       age  \
# bbb_accred                  0.214923    0.156313    0.096591  0.196180
# cn_rated                    0.000000    0.126813    0.269074 -0.071478
# cn_overall                  0.893457   -0.266499    0.276612  0.026314
# cn_acct_transp              0.621742   -0.174276   -0.028676  0.102151
# cn_financial                0.897633   -0.271244    0.281491  0.003011
# percent_admin              -0.373093   -0.169904   -0.068708 -0.056185
# percent_fund               -0.943801    0.287388   -0.138191  0.167908
# percent_program             1.000000   -0.226968    0.145216 -0.145946
# staff_size                 -0.226968    1.000000    0.426592  0.449038
# board_size                  0.145216    0.426592    1.000000  0.504027
# age                        -0.145946    0.449038    0.504027  1.000000
# total_contributions        -0.221514    0.997359    0.430014  0.011183
# total_expenses             -0.190034    0.997426    0.429103  0.092253
# total_revenue              -0.187766    0.997274    0.432487  0.137573
# twitter_followers           0.175008   -0.149436    0.117911 -0.100400
#
#                      total_contributions  total_expenses  total_revenue  \
# bbb_accred                     -0.252711       -0.266936      -0.266799
# cn_rated                        0.000000        0.000000       0.000000
# cn_overall                     -0.093878       -0.068735      -0.066852
# cn_acct_transp                  0.063556        0.064774       0.064702
# cn_financial                   -0.124588       -0.097166      -0.095069
# percent_admin                  -0.199115       -0.146261      -0.143338
# percent_fund                    0.310256        0.257404       0.253915
# percent_program                -0.221514       -0.190034      -0.187766
# staff_size                      0.997359        0.997426       0.997274
# board_size                      0.430014        0.429103       0.432487
# age                             0.011183        0.092253       0.137573
# total_contributions             1.000000        0.971910       0.968796
# total_expenses                  0.971910        1.000000       0.999907
# total_revenue                   0.968796        0.999907       1.000000
# twitter_followers              -0.191576       -0.196378      -0.195392
#
#                      twitter_followers
# bbb_accred                    0.132839
# cn_rated                      0.194382
# cn_overall                    0.142002
# cn_acct_transp                0.223734
# cn_financial                  0.123382
# percent_admin                -0.107855
# percent_fund                 -0.150382
# percent_program               0.175008
# staff_size                   -0.149436
# board_size                    0.117911
# age                          -0.100400
# total_contributions          -0.191576
# total_expenses               -0.196378
# total_revenue                -0.195392
# twitter_followers             1.000000
#
# [15 rows x 15 columns]

# %%
combined_panda.staff_size.describe()
# Out:
# count      24.000000
# mean       86.750000
# std       282.660382
# min         1.000000
# 25%         8.000000
# 50%        17.500000
# 75%        31.750000
# max      1400.000000
# Name: staff_size, dtype: float64

# %%
sum(combined_panda.staff_size==0)
# Out:
# 0
