# %%
import numpy as np
import scipy.stats as st
import sklearn.linear_model as lm
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
f = lambda x: np.exp(3*x)
type(f)
# Out:
# function

# %%
x_tr = np.linspace(0., 2, 200)
y_tr = f(x_tr)

# %%
x = np.array([0., .1, .2, .5, .8, .9, 1])
y = f(x) + np.random.randn(len(x))

# %%
plt.figure(figsize=(6,3));
plt.plot(x_tr[:100], y_tr[:100], '--k')
plt.plot(x, y, 'ok', ms=10);

# %%
lr = lm.LinearRegression()

# %%
type(lr)
# Out:
# sklearn.linear_model.base.LinearRegression

# %%
lr.fit(x[:, np.newaxis], y);

# %%
y_lr = lr.predict(x_tr[:, np.newaxis]);

# %%
plt.figure(figsize=(6,3));
plt.plot(x_tr, y_tr, '--k');
plt.plot(x_tr, y_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.xlim(0, 1);
plt.ylim(y.min()-1, y.max()+1);
plt.title("Linear regression");

# %%
lrp = lm.LinearRegression()
plt.figure(figsize=(6,6));
plt.plot(x_tr, y_tr, '--k');

for deg, s in zip([2, 5], ['-', '.']):
    lrp.fit(np.vander(x, deg + 1), y);
    y_lrp = lrp.predict(np.vander(x_tr, deg + 1));
    plt.plot(x_tr, y_lrp, s, label='degree ' + str(deg));
    plt.legend(loc=2);
    plt.xlim(0, 1.4);
    plt.ylim(-10, 40);
    print(' '.join(['%.2f' % c for c in lrp.coef_]))
plt.plot(x, y, 'ok', ms=10);
plt.title("Linear regression");
# Out:
# 22.68 -5.54 0.00
# 135.20 -304.24 253.44 -79.26 13.94 0.00

# %%
ridge = lm.RidgeCV()
plt.figure(figsize=(6,3));
plt.plot(x_tr, y_tr, '--k');

for deg, s in zip([2, 5], ['-', '.']):
    ridge.fit(np.vander(x, deg + 1), y);
    y_ridge = ridge.predict(np.vander(x_tr, deg + 1));
    plt.plot(x_tr, y_ridge, s, label='degree ' + str(deg));
    plt.legend(loc=2);
    plt.xlim(0, 1.5);
    plt.ylim(-5, 80);
    print(' '.join(['%.2f' % c for c in ridge.coef_]))
plt.plot(x, y, 'ok', ms=10);
plt.title("Ridge regression");
# Out:
# 11.15 5.44 0.00
# 3.93 3.71 3.52 3.41 3.49 0.00

# %%
#http://nbviewer.ipython.org/github/donnemartin/data-science-ipython-notebooks/blob/master/scikit-learn/scikit-learn-k-means.ipynb
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import seaborn; 
from sklearn.linear_model import LinearRegression
from scipy import stats
import pylab as pl

seaborn.set()

# %%
from sklearn import neighbors, datasets

iris = datasets.load_iris()

X, y = iris.data, iris.target
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca.fit(X)
X_reduced = pca.transform(X)
print("Reduced dataset shape:", X_reduced.shape)

import pylab as pl
pl.scatter(X_reduced[:, 0], X_reduced[:, 1], c=y,
           cmap='RdYlBu')

print("Meaning of the 2 components:")
for component in pca.components_:
    print(" + ".join("%.3f x %s" % (value, name)
                     for value, name in zip(component,
                                            iris.feature_names)))
# Out:
# ('Reduced dataset shape:', (150, 2))
# Meaning of the 2 components:
# 0.362 x sepal length (cm) + -0.082 x sepal width (cm) + 0.857 x petal length (cm) + 0.359 x petal width (cm)
# -0.657 x sepal length (cm) + -0.730 x sepal width (cm) + 0.176 x petal length (cm) + 0.075 x petal width (cm)
# /usr/lib/pymodules/python2.7/matplotlib/font_manager.py:1236: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /usr/lib/pymodules/python2.7/matplotlib/font_manager.py:1246: UserWarning: findfont: Could not match :family=Bitstream Vera Sans:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0. Returning /usr/share/matplotlib/mpl-data/fonts/ttf/cmb10.ttf
#   UserWarning)

# %%
from sklearn.cluster import KMeans
k_means = KMeans(n_clusters=3, random_state=0) # Fixing the RNG in kmeans
k_means.fit(X)
y_pred = k_means.predict(X)

pl.scatter(X_reduced[:, 0], X_reduced[:, 1], c=y_pred,
           cmap='RdYlBu');

# %%
import pymysql as mdb
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
mysqlauth = pd.DataFrame.from_csv('/home/kristy/Documents/auth_codes/mysql_user.csv')
sqluser = mysqlauth.username[0]
sqlpass = mysqlauth.password[0]

con = mdb.connect(user=sqluser, host="localhost", db="charity_data", password=sqlpass, charset='utf8')

# %%
disease_list = ["breast_cancer", "alzheimer", "parkinson", "diabetes", "dyslexia",
                "leukemia", "osteoporosis", "lung_cancer", "blindness", "multiple_sclerosis",
                "crohn", "colon_cancer"]
combined_panda = pd.DataFrame()
with con:
    for disease in disease_list:
        panda_char = pd.read_sql("SELECT * FROM " + str(disease), con)
        combined_panda = pd.concat([combined_panda, panda_char], ignore_index=True)

# %%
combined_panda.shape
# Out:
# (114, 17)

# %%
dfwithnums = combined_panda[combined_panda['cn_overall']>0]

# %%
dfwithnums.columns
# Out:
# Index([u'address', u'bbb_accred', u'bbb_link', u'city', u'cn_acct_transp', u'cn_financial', u'cn_link', u'cn_overall', u'cn_rated', u'disease', u'facebook_likes', u'facebook_link', u'id', u'link', u'name', u'twitter_followers', u'twitter_link'], dtype='object')

# %%
plt.figure(figsize=[6,3])
plt.hist(combined_panda[combined_panda['cn_overall']>0]['cn_overall'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-85945133a9a8> in <module>()
#       1 plt.figure(figsize=[6,3])
# ----> 2 plt.hist(combined_panda[combined_panda['cn_overall']>0]['cn_overall'])
#
# /usr/lib/pymodules/python2.7/matplotlib/pyplot.pyc in hist(x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, hold, **kwargs)
#    2825                       histtype=histtype, align=align, orientation=orientation,
#    2826                       rwidth=rwidth, log=log, color=color, label=label,
# -> 2827                       stacked=stacked, **kwargs)
#    2828         draw_if_interactive()
#    2829     finally:
#
# ...

# %%
type(combined_panda['cn_overall'][0])
# Out:
# numpy.float64
